# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import csv
from time import sleep
import requests
import time

list_of_name = []
list_of_experience = []
list_of_about = []
list_of_address = []
list_of_job_title = []
list_of_description = []
list_of_skills =[]

profile_address = open('C:/Users/kumaramar/OneDrive - Microsoft/hackathon/Auto_Email/profile_addresses.txt')
urls = profile_address.read().split('\n')
total_profile=len(urls)

credential = open('C:/Users/kumaramar/OneDrive - Microsoft/hackathon/Auto_Email/credentials.txt')
line = credential.readlines()
username = line[0]
password = line[1]
credential.close()
print('- Finish importing the login credentials')
sleep(2)

t1 = time.time()
print('Start-time: ', t1)


s = Service('C:/Users/kumaramar/OneDrive - Microsoft/hackathon/Auto_Email/chromedriver.exe')
driver = webdriver.Chrome(service=s)
driver.get('https://www.linkedin.com')
sleep(3)
driver.find_element(By.ID, 'session_key').send_keys(username)
driver.find_element(By.ID, 'session_password').send_keys(password)
sleep(2)
log_in_button = driver.find_element(By.CLASS_NAME, "sign-in-form__submit-button")
sleep(1)
log_in_button.click()
sleep(15)

for profile_link in urls:
    print('------------------')
    try:
        driver.get(profile_link)
        sleep(15)
#NAME
        name = driver.find_element(By.XPATH, "//h1[@class='text-heading-xlarge inline t-24 v-align-middle break-words']")
        list_of_name.append(name.text)
        sleep(5)
    except:
        print('Error in profile: ', profile_link)
        list_of_name.append('')
        list_of_experience.append([])
        list_of_about.append([])
        list_of_address.append([''])
        list_of_job_title.append('')
        list_of_description.append([])
        list_of_skills.append([])
        continue

    
# TITLE
    title = driver.find_element(By.XPATH, "//div[@class='text-body-medium break-words']")
    list_of_job_title.append(title.text)
    
# ADDRESS
    address = driver.find_elements(By.XPATH, "//span[@class='text-body-small inline t-black--light break-words']")
    location=[]
    for j in address:
        location.append(j.text)
        list_of_address.append(location)
    

#-----------------------------------BeautifulSoup--------------------------
    src = driver.page_source
    doc = BeautifulSoup(src, 'html.parser')
    div = doc.find_all('section', class_='artdeco-card ember-view relative break-words pb3 mt2')

# ABOUT
    about_section_present= False
    for section in div:
        about_section = section.find_all('div', {'id': 'about'})
        if len(about_section) != 0:
            about_section_present=True
            about_text= section.find_all('span', {'class': 'visually-hidden'})
            about_each=[]
            for bio in about_text:
                about_each.append(bio.text)
            list_of_about.append(about_each)
            break;
    if about_section_present == False: 
        about_each=[]
        list_of_about.append(about_each)
        
# CHECK FOR SKILL AND EXPERIENCE SECTION
    skill_section_present= False
    experience_section_present=False
    
    for section in div:
        skill_section = section.find_all('div', {'id': 'skills'})
        if len(skill_section) != 0:
            skill_section_present=True
            break
    
    for section in div:
        exp_section = section.find_all('div', {'id': 'experience'})
        if len(exp_section) != 0:
            experience_section_present=True
            break
    
    get_url = driver.current_url


# EXPERIENCE

    if experience_section_present==True:
        sleep(3)
        driver.get(get_url+"details/experience")
        sleep(7)
        src2 = driver.page_source
        doc2 = BeautifulSoup(src2, 'html.parser')
        exp_list = doc2.find_all('li', {'class':'pvs-list__paged-list-item artdeco-list__item pvs-list__item--line-separated'})
        
        experience_per_person=[]
        for each_exp in exp_list:
            text_line_list= each_exp.find_all('span', {'class': 'visually-hidden'})
            partition_list=[]
            for text_line in text_line_list:
                partition_list.append(text_line.text)
            experience_per_person.append(partition_list)
        list_of_experience.append(experience_per_person)
        
        

# SKILLS
   
    if skill_section_present==True:
        sleep(3)
        driver.get(get_url+"details/skills")
        driver.maximize_window()

        SCROLL_PAUSE_TIME = 0.8
#-----------------------------------------------
        # Get scroll height
        last_height = driver.execute_script("return document.body.scrollHeight")

        while True:
            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            # Wait to load page
            sleep(SCROLL_PAUSE_TIME)

            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

#------------------------------------------------                
        print("Scrolling is over")   
        sleep(5)
        skill_each=[]
        src1 = driver.page_source
        doc1 = BeautifulSoup(src1, 'html.parser')
        div1 = doc1.find_all('li', {'class':'pvs-list__paged-list-item'}) 

        for li in div1:
            only_skill=[]
            skill_text= li.find_all('span', {'class': 'visually-hidden'})
            for skills in skill_text:
                only_skill.append(skills.text)
            skill_each.append(only_skill[0])
        list_of_skills.append(list(set(skill_each)))

    elif skill_section_present == False: 
        skill_each=[]
        list_of_skills.append(skill_each)
        
    
# print(list_of_name)
# print(list_of_job_title) 
# print(list_of_address)
# print(list_of_about)
# print(list_of_experience)
# for m in list_of_skills:
#     print(len(m),m)
sleep(8)
driver.quit()

t2 = time.time()
print('End-time: ', t2)
print('Total time taken: ', (t2-t1)/60, 'minutes\t', 'Profiles scraped: ', total_profile)
# Out:
# - Finish importing the login credentials
# Start-time:  1663430665.593765
# ------------------
# Scrolling is over
# ------------------
# Scrolling is over
# ------------------
# Scrolling is over
# ------------------
# Error in profile:
# End-time:  1663430844.9726696
# Total time taken:  2.989648409684499 minutes	 Profiles scraped:  4

# %%
list_of_experience
# Out:
# [[['Director, Data and Business Intelligence',
#    'Coda Payments',
#    'Jan 2021 - Present · 1 yr 9 mos',
#    'Singapore'],
#   ['GoBear',
#    '5 yrs 7 mos',
#    'Singapore',
#    'Director, Technical Product Management',
#    'Jan 2019 - Dec 2020 · 2 yrs',
#    'Director Of Analytics',
#    'Jan 2018 - Dec 2018 · 1 yr',
#    'Data Scientist',
#    'Jun 2015 - Dec 2017 · 2 yrs 7 mos'],
#   ['Actuary Data Analyst',
#    'Aon',
#    'Jan 2014 - May 2015 · 1 yr 5 mos',
#    'Singapore']],
#  [['Head of Product, Data & Analytics',
#    'Narvar · Full-time',
#    'Mar 2022 - Present · 7 mos'],
#   ['Volunteer',
#    'Court Appointed Special Advocates of Philadelphia · Freelance',
#    'Jan 2021 - Present · 1 yr 9 mos'],
#   ['VP, Global Business Solutions, Data Product Management',
#    'Fiserv · Full-time',
#    'Mar 2021 - Feb 2022 · 1 yr'],
#   ['Senior Director',
#    'Verifone · Full-time',
#    'Mar 2020 - Mar 2021 · 1 yr 1 mo'],
#   ['Bed Bath & Beyond',
#    '6 yrs 1 mo',
#    'Sr. Director',
#    'May 2019 - Mar 2020 · 11 mos',
#    'Union, New Jersey',
#    'Director and Oversight, Store Technologies',
#    'Nov 2017 - May 2019 · 1 yr 7 mos',
#    'Union, New Jersey',
#    'Senior Manager',
#    'Oct 2015 - Nov 2017 · 2 yrs 2 mos',
#    'Union, New Jersey',
#    'Spearheaded cradle-to-grave product strategies and vision, with full ownership of business plans, roadmaps, P&L and budgets.  \n\n\uf0a7\tResponsible for the product roadmap for the Point of Sale (POS) & Payments products, average annual budget of ~$15 mil\n\uf0a7\tSuccessfully launched the EMV and Point to Point Encryption/Tokenization program across ~1500 stores in North America (USA, Canada, Mexico, and Puerto Rico), a ~$20 million program saving the company ~$10 mil in 2016 alone\n\uf0a7\tConducted cost benefit analysis and vendor selection analysis \n\uf0a7\tMet with the CFO and COO on a weekly basis to highlight the progress of the various strategic initiatives\n\uf0a7\tPoint of Contact with cross functional teams like Operations, Finance, Marketing, Loss Prevention, etc. to integrate business requirements into product lifecycle\n\uf0a7\tResponsible for coordinating development deliverables of 5 vendor teams spread across USA and Canada and 2 internal teams. Total dedicated team strength across all vendors and internal teams is ~50 team members\n\uf0a7\tWorked with project team and project stakeholders to establish service level agreements\n\uf0a7\tDeveloped and initiated internal processes to improve program delivery within specific timeframes\n\uf0a7\tDefined the resources required for different projects and allocated resources accordingly',
#    'Manager',
#    'Mar 2014 - Oct 2015 · 1 yr 8 mos'],
#   ['Senior Consultant',
#    'Daugherty Business Solutions',
#    'Jul 2013 - Mar 2014 · 9 mos',
#    'Greater St. Louis Area'],
#   ['Associate',
#    'TresVista Financial Services',
#    'Jan 2012 - Jun 2013 · 1 yr 6 mos'],
#   ['Product Manager',
#    'DDC Advocacy',
#    'Mar 2006 - Dec 2011 · 5 yrs 10 mos',
#    'Alexandria, Virginia',
#    'Formulate the strategy, core features/functionality and production road maps for the product portfolio. Lead full software development life cycle management for products owned and define product enhancements requirements. Analyze consumer research data for improved business plans, market positioning, and strategic brand planning. \nPerform scenario analyses to align operational and financial resources with growth objectives.\nContributed to the development and implementation of the company´s short and long term strategic plan. \nEnlisted stakeholders to fund projects. Specified enhancements and work plans for offshore technology teams. \nLiaised with business and functional managers during risk engineering and high-level review sessions to derive and execute action plans to meet deadlines and standards.'],
#   ['DC Coordinator',
#    'Vibha, Inc',
#    'Jan 2008 - Dec 2008 · 1 yr',
#    'Served as the coordinator of the DC chapter of Vibha. Led efforts to organize 3 major fund raising events in 2008. Annual funds raised were $28,000 with an attendance of almost 1500 people combined for the 3 events.'],
#   ['Account Manager',
#    'AMERICAN INFOSERV, INC',
#    'May 2004 - Feb 2006 · 1 yr 10 mos',
#    'Consulted to Merrill Lynch, Neopost, and Pfizer to define business objectives, systemic needs and strategic data management solutions. \nOrchestrated product design, testing, and production in collaboration with system analysts, software engineers/ architects, to produce both high-level and detailed application models that satisfied client commitments.\nCoached team through 15-month design-to-production product cycle; hired for key assignments.'],
#   ['Student Manager',
#    'Syracuse University',
#    'Jan 2003 - May 2004 · 1 yr 5 mos',
#    "I worked part time at the Student Food Services at Syracuse University while studying for my Master's in Electrical Engineering. As a manager for the student services, I was responsible for running the day to day operations of Haven Hall, managing 10-20 full and part time employees. The team I managed was very diverse, ranging from international students to full time employees at Syracuse University. Responsibilities included resource allocation, budgeting, cost reduction strategy implementation, and maintaining high levels of customer service. \n\nI was also responsible managing events at the Syracuse University stadium Carrier Dome during various sports events. Daily foot traffic for these events ranged from 2000-5000 customers. I was responsible for resource allocation, managing personnel, inventory control, and accounting."]],
#  [['Chief Technology Officer',
#    'Proton · Full-time',
#    'Apr 2015 - Present · 7 yrs 6 mos',
#    'Geneva, Switzerland',
#    "I shape the technical direction of our software development efforts and serve on the company's executive leadership team. I have been at Proton since nearly the beginning and have been involved in the design of a large number of core architecture and product features."],
#   ['Principal Data Scientist',
#    'AT&T',
#    'Oct 2013 - Apr 2015 · 1 yr 7 mos',
#    'Palo Alto, California',
#    'Scalable algorithm design and prototyping. Build proof of concept data products.'],
#   ['Post-doctoral Research Scientist',
#    'Harvard University',
#    'Dec 2012 - Sep 2013 · 10 mos',
#    'Geneva Area, Switzerland',
#    "I worked on the ATLAS experiment at the Large Hadron Collider. I directed an analysis group searching for weakly-produced supersymmetric decays involving a Higgs boson. I was also the primary developer of the group's analysis code and petabyte-to-gigabyte data reduction tools."],
#   ['Graduate Research Assistant/Ph.D. Candidate',
#    'SLAC National Accelerator Laboratory',
#    'Sep 2006 - Dec 2012 · 6 yrs 4 mos',
#    'Menlo Park, California',
#    'I was a Stanford University graduate student working for the ATLAS group (http://www.atlas.ch). I was a major contributor and leader in both the planning and execution of several iterations of two well-motivated new physics searches, and proposed novel search strategies which were subsequently exploited for large new physics sensitivity improvement. I made significant contributions to ATLAS physics as a whole, in particular in the areas of heavy flavor tagging, track-jet reconstruction, and software validation/debugging.']],
#  [['Chief Technology Officer',
#    'Coda Payments · Full-time',
#    'Feb 2022 - Present · 8 mos',
#    'Singapore',
#    'I’m extremely excited to be joining the amazing team at Coda, focused on building the platform of choice for taking life’s digital experiences over the top. This is an industry that’s evolving and growing rapidly, and we’re committed to scaling our tech team to meet the challenges that come with delivering complex products at massive scale, all requiring best-in-class security and compliance. If you’re an engineer, engineering manager, or other tech professional who has a high sense of ownership, come join me! Coda has a distributed tech team across Asia, Europe, and the Americas, with a highly collaborative and positive culture.'],
#   ['SVP Engineering',
#    'Agoda · Full-time',
#    'Aug 2016 - Feb 2022 · 5 yrs 7 mos',
#    'Bangkok Metropolitan Area, Thailand',
#    "Working with some great people to build the world's best online travel booking destination. Grew the engineering team, hiring hundreds of developers from all over the world. Together we grew our hotel business by several times, as well as built new product lines including flights, attractions, packages, and more."],
#   ['Gracenote',
#    '5 yrs 4 mos',
#    'San Francisco Bay Area',
#    'VP Technology Strategy',
#    'May 2015 - Aug 2016 · 1 yr 4 mos',
#    'Responsible for the technology side of M&A, due diligence, strategic sales, and engineering integration at Gracenote. Also managing large global engineering teams of recently acquired companies.',
#    'VP Engineering',
#    'May 2011 - May 2015 · 4 yrs 1 mo',
#    'Responsible for growing and managing the engineering team (100s of engineers). Built and maintained the largest media information database in the world. Built systems to process, ingest, link, and store metadata about music, video/television, and other entertainment verticals. Led teams building cutting edge editorial and data processing tools. Managed diverse and voluminous data. Built and powered many data export and API products. Responsible for all data systems architecture.\n\nOther responsibilities include:\n- Management of both onshore and offshore development resources\n- Intense collaboration with global offices\n- Technical due diligence for potential acquisitions\n- Integration of acquisitions'],
#   ['Advisor',
#    'ApptheGame, Inc',
#    '2011 - 2014 · 3 yrs',
#    'San Francisco Bay Area',
#    'Served as a technical advisor to start-up ApptheGame (Swoopt), assisting with early stage hiring, system architecture, and technology strategy. The company was acquired by theScore in late 2014.'],
#   ['Owner',
#    'Feldkamp Consulting · Full-time',
#    'May 2007 - May 2011 · 4 yrs 1 mo',
#    'Small software consulting shop located in Minneapolis building software for the Media / Entertainment industry. Clients included:\n\n - Sony / Gracenote (NYSE:SNE)\n - Rovi (NASDAQ:ROVI)\n - Mix and Burn / Trans World Entertainment (NASDAQ:TWMC)'],
#   ['Digital Media Development Manager',
#    'Trans World Entertainment / Musicland Group · Full-time',
#    'May 2004 - Jul 2007 · 3 yrs 3 mos',
#    'Managed and grew engineering team, first at Musicland, then Transworld (post acquisition of Musicland). Led software development for several digital initiatives designed to transform and digitize media retail experiences. Built kiosk-based solutions to sell digital music and sell/print on-demand posters across 1000+ stores.'],
#   ['Senior Engineer, Development Manager, other roles',
#    'AllMusic · Full-time',
#    'Jun 1999 - May 2004 · 5 yrs',
#    'Ann Arbor, Michigan, United States',
#    "Started as an engineer building software systems to extract, analyze, and database music and video content. We built distributed computing models and distributed data processing back before it was cool. Created the world's largest database of music at the time, and built a system to extract representative song clips to drive both in-store and online music sales. Later moved into hands on management, leading teams to build audio recognition systems, content management systems, and lots of other fun stuff.\n\nLater, All Media Guide was acquired by Rovi Corporation."]],
#  [['Chief Technology Officer',
#    'Cendyn · Full-time',
#    'Mar 2020 - Present · 2 yrs 7 mos',
#    'Boca Raton, Florida, United States'],
#   ['CTO',
#    'ERP Maestro, Inc',
#    'Jan 2018 - Mar 2020 · 2 yrs 3 mos',
#    'Plantation, Florida, United States',
#    'CTO'],
#   ['Technology Consultant',
#    'Consultant',
#    'May 2015 - Jan 2018 · 2 yrs 9 mos',
#    'Miami/Fort Lauderdale Area',
#    'Looking for a challenging opportunity in an energetic and motivated technology company.  I want to apply my years of product and technology innovation and management to a leading edge and fast paced company culture and environment.  I want to take my proven record of successful development or teams and products to the next level and help drive your company to greater success.'],
#   ['Consultant',
#    'Kaplan University',
#    'May 2017 - Sep 2017 · 5 mos',
#    'Fort Lauderdale, Florida'],
#   ['Senior Director, Data Management Platform and Targeting',
#    'Yahoo!',
#    'Jan 2010 - Mar 2015 · 5 yrs 3 mos',
#    'Sunnyvale Ca',
#    'Managed Yahoo engineering teams across two continents including system development, big data ingestion and analysis, audience data warehouse, and data modeling related to user targeting and first/third party data acquisition. \n- Utilized agile based development processes, integrating Product, Engineering and Support\n- Implemented next generation Data Acquisition Platform using high performance web services for first/third party data integration system utilizing Hadoop cluster, Zookeeper and Oracle DB.\n- Development of Audience Data Warehouse utilizing Hadoop and Druid technology providing for a robust, scalable and near real-time analytic and reporting platform.\no\tDevelopment of Objective Based Targeting system using Hadoop and search based technology.    \n \nVP Engineering (Genome) - Led the engineering activities and teams at Genome developing systems for premium targeted online advertising solutions. Genome (interclick) was a public company that was acquired by Yahoo. interclick’s proprietary advertising and advanced user targeting technology solutions enabled it to dramatically improve data targeted solutions and optimized returns for advertisers across a variety of pooled premium supply (website) sources. \n- Development of application and systems utilizing Microsoft technology such as Visual Studio/C# and SQL Server.\n  - Audience targeting and Ad management applications\n  - Ad serving system\n  - Third Party Data Integration platform\n  - Directed the development of Business Intelligence system utilizing three tiered model using Microstrategy, Infomatica and Netezza (later Vertica).  \n  - Development of event based analytic/targeting DB utilizing in memory version of ParAccel. System handled 1 billion user records, ~20k events/sec  and data storage of about 32gbytes per day.\n  - Development of high performance user profile and lookup system to serve real time ad serving. Based on AeroSpike (NoSQL) technology storing user profiles for ~250 million active users.',
#    'Interclick: The Art of Buying High to Sell Higher',
#    'Yahoo Maps Out Genome Ad Strategy',
#    "Rough as the past year has been for Yahoo, one of the company's more head-scratching moves may yet prove beneficial. Last November, Yahoo snatched up Interclick for $270 million, leaving many in the industry to wonder, what does Yahoo need with yet..."],
#   ['DayJet Technologies',
#    '7 yrs 5 mos',
#    'VP Engineering, Systems',
#    'Sep 2008 - Jan 2010 · 1 yr 5 mos',
#    'Miami/Fort Lauderdale Area',
#    'System and application software for On-Demand, fractional and commercial regional air carriers.\n\n•\tPlayed an integral part in defining company’s initial business strategy and helped refine business plan and financing strategy including market strategy and financial models including ASP and customized product models.\n•\tDeveloped strategic plans for the productization of the aviation technology for both domestic and international markets.\n•\tLed Systems development system design, implementation, QA and deployment.\n•\tTook key role in transitioning team from DayJet Corporation to DayJet Technologies including all finance, operations and human resource activities.\n•\tPlayed key role customer briefings and sales lead activities.\n•\tLead Project Management activities with customers, partners and vendors including requirement analysis, project scoping, project sizing and scheduling.\n•\tManaged all banking, general administration, health insurance, payroll and human resource activities. ',
#    'VP Systems and Technology',
#    'Sep 2002 - Sep 2008 · 6 yrs 1 mo',
#    'Responsible for architecting, building and managing all internally developed systems required run DayJet’s On-Demand Airline.\n\n•\tBuilt engineering team from scratch to a team of 35 technical professionals including development, quality assurance, technical publications, release management and technical support. \n•\tLead Systems development activities through three major releases in addition to numerous versions and patches.\no\tAutomated flight operations system\no\tCustomer reservation web portal\no\tElectronic flight bag application (windows application running on tablet PC) for pilots\no\tCustomer support web portal\n•\tMember of Executive management team with responsibility for overall technology strategy and systems development.\n•\tHelped coordinate and perform business intelligence and data analysis activities for business process improvement, marketing/sales initiatives, system tuning and management reporting.\n•\tWorked with IT architects in defining infrastructure required to support 24x7, scalable and highly available operational business and systems. \n•\tPart of cross departmental operations team tasked with improving flight operations activities utilizing daily post mortem reviews and provided/implemented improvement recommendations.\n•\tLead all technical Due Diligence activities with investors and consultants as part of fund raising team during multiple rounds of fund raising activities over 5 years.\n•\tArchitected and managed million dollar software contact with Eclipse Aviation for the development of an aircraft data acquisition and routing system and data center.\no\tWorked with IT team to define data center hosting proposal for Eclipse Aviation.\n•\tCoordinated ERP systems integration, with all internally developed systems. \n•\tManaged level 2 and 3 technical support for DayJet’s 24x7 flight operations systems. ',
#    'Taxis in the Sky',
#    "OPENING-DAY GLAMOUR A passenger leaves an Eclipse on a Boca Raton runway on the first day of DayJet's on-demand air-taxi service True, a cover story I wrote for this magazine seven years ago, contending that the era of tiny, convenient, and relatively..."],
#   ['VP Engineering',
#    'Adir Technologies/NetSpeak',
#    '1996 - 2002 · 6 yrs',
#    'Miami/Fort Lauderdale Area',
#    'Vice President, Software Product Development; A Privately-held venture funded by Cisco Systems, Net2Phone Corporation, and Softbank Infrastructure Fund. \n\n•\tManage organization composed of approximately 25 software engineering professionals.\n•\tLead Product Development activities\no\tDeveloped and fielded Advanced Routing Manager and Provisioning Manager as add-ins to Cisco-powered Voice over Internet Protocol (VoIP) Networks.\no\tInitiated and developed new high performance VoIP Advanced Routing Manager with 4X performance improvement over previous release.\no\tMoved Network Element Management Application from MS Windows application to Java based application.\n•\tWorked jointly with Cisco Systems and customers on coordinated projects, product and customer requirements.\n•\tWorked closely with marketing, sales, technical support and senior management to develop product roadmap, resource plans and budgets. ',
#    'NetSpeak bets on Net phones',
#    'The nascent Net telephony software firm is getting investments from heavy hitters--an indication that many want a piece of the relatively uncharted area.'],
#   ['Software Engineering Manager',
#    'Motorola',
#    'Dec 1994 - Dec 1995 · 1 yr 1 mo',
#    'Boynton Beach, FL',
#    'Joined Motorola as a software development manager in a newly formed software engineering group developing both embedded and PC based software for two-way wireless products. The two-way pager PC based client software allowed users to send and receive pages through Motorola’s two-way pager using a serial interface to pager.  \n*\tDesigned, developed, tested and shipped Window’s based application as part of the two-way pager product.\n*\tManaged Product Development Team including scheduling, resource allocation and problem resolution as well as software process activities \n*\tWas the main focal point for interaction with System test, Technical Assistance and Support, Sales, Hardware development groups and Marketing'],
#   ['Senior Software Engineer',
#    'IBM',
#    'Jul 1983 - Nov 1994 · 11 yrs 5 mos',
#    'Boca Raton, Florida',
#    'Joined IBM as a software engineer directly out of college. During my eleven years with IBM I held numerous software engineering functions and positions of increasing scope and responsibility.\n•\tLead Architect for OS/2 Multimedia Subsystem  \n\tProvided the multimedia architecture of the portable operating system Workplace OS\n•\tTeam lead and programmer for OS/2 Multimedia Subsystem\n\tDeveloped 2 releases of the OS/2 Multimedia Subsystem application interface component\n•\tVideotex programmer for Series 1 system \n•\tPerformance modeling and simulation of disk and communication subsystem\n\tDeveloped simulation models for disk and communication subsystem in order to evaluate capacity and performance ']],
#  [['Head of Data & Business Intelligence',
#    'ICONIQ Capital · Full-time',
#    'Aug 2020 - Present · 2 yrs 2 mos',
#    'San Francisco Bay Area',
#    'Responsible for driving & leading a range of Data & BI related functions including Data Management, Reporting/Analytics, Process Automation & Governance at the enterprise level.  \nOwn & drive data/information strategy across different business functions- build a robust/scalable EDW (Enterprise Data Warehouse)/single source of truth for the firm. \nIntegrating data into Snowflake from - CRM, Custodians, Fund Admins, General Ledger/Shadow Accounting, Alt Data/3rd party sources (Pitchbook, LinkedIn, SourceScrub, etc.), Market Data & Transactions.\nLeverage data science/machine learning techniques to provide augmented analytics (like generating business insights & leading indicators for investment/deal sourcing teams).  \nLive Dashboards in Tableau for tracking KPIs.\nDeploy Software Robots using RPA tools (UiPath) to automate manual tasks like data extraction, website downloads, etc.\nBuild & Lead a team of strong/fungible Data/Full-Stack engineers.\nProvide end to end oversight of strategic & tactical projects to ensure smooth delivery to the end-users in Operations, Finance, Legal/Compliance, Investment Team, Client Services.\nCollaborate with business stakeholders to identify opportunities & risks in their daily operations & align technology solutions accordingly.  Convert Functional Requirements into Technical Specifications. \nTrack usage & engage with department leads on a regular basis to ensure they have all the necessary tools/resources for technology adoption.',
#    'Skills: Deal Sourcing · Data Warehousing · SDLC · Business Intelligence · Software Project Management · Artificial Intelligence (AI) · Portfolio Analytics · Machine Learning · Data Science · Salesforce Sales Cloud · Robotic Process Automation (RPA) · IT Strategy'],
#   ['Credit Suisse',
#    '7 yrs 9 mos',
#    'Global Head of Data Management',
#    'Apr 2015 - Aug 2020 · 5 yrs 5 mos',
#    'New York City Metropolitan Area',
#    'Global Head of Data Management responsible for sourcing, maintaining and distributing critical (transactional & reference) data to front office & back office applications in global markets (Investment Banking). \nResponsible for Building/Maintaining Central Data Warehouse & Reference Data Systems within Prime Services.\n\nProvide Design/Architecture for a variety of Data Related Strategic & Regulatory projects across Global Markets including Prime Brokerage, Stock Loan, Equity Financing, Fixed Income/Repos/Trade Management, Listed Derivatives  & cOTC, Risk/Margin, Reference Data, MDM, Commission & Fee, Client Reporting, Financial Reporting (CCAR, MIFID, FATCA). \n\nProvide data services using browser based solutions for business/operations users.\n\nAs a Data Management lead, own the data/information strategy & execution, understand the target architecture, provide governance & business reporting/analytics. \n\nCollaborate with cross-functional IT & Business groups for end to end implementation of projects.\nRationalize/Consolidate Data across the business units & simplify the architecture.\n\nProgram Management - Responsible for planning and directing global projects within prime services, Gather functional/regulatory requirements & transform them into technical product/specifications ensuring it meets the needs of the end users across the platforms and also adheres to the enterprise architecture & Bank standards.\n\nProvide Market Reference data (Instrument static/Market Pricing/Corp Actions/Dividends/Account Master) to different business lines like Brokerage, Swaps, Fixed Income, Derivatives, Stock Loan & Risk Systems.\n\nIT Budgeting and planning, Resource Management (~25 people globally)\n\nTCO optimization for Data Infrastructure\n\nDev Ops Integration - Automation of Development, Testing & Deployment. Migration to Cloud/VPC (AWS).\n\nClient Management -  Work with the clients directly to support business reporting & analytics.',
#    'Skills: Data Warehousing · SDLC · Business Intelligence · Software Project Management · Artificial Intelligence (AI) · Machine Learning · Data Science · Salesforce Sales Cloud · Robotic Process Automation (RPA) · IT Strategy',
#    'Data Warehouse Development Lead',
#    'Dec 2012 - Apr 2015 · 2 yrs 5 mos',
#    'One Madison Ave, New York, NY - 10010',
#    'Data Warehouse Development Lead responsible for Design/Development/Implementation of Data & Reporting flows within Prime Services. \nGather User requirements for Strategic/Regulatory projects.\nOwn & Lead end to end projects within Prime Services involving global applications.\nRationalize the legacy Data & Reporting flows to improve client report SLAs.\nDesign/Develop/Implement data flows within Risk flows.\nSource Market Data Feeds from external vendors like BBG, Reuters, Telekurs, etc.\nRisk/Valuation Models - Gather requirements/Design/Develop reports to provide Risk Valuation Models for (external) Regulators.',
#    'Skills: Data Warehousing · SDLC · Business Intelligence · Software Project Management'],
#   ['Senior Data Warehouse & Business Intelligence Solutions Architect',
#    'Barclays Investment Bank',
#    'May 2012 - Dec 2012 · 8 mos',
#    '70 Hudson St, Jersey City, NJ',
#    'BI & Data Warehouse Lead Architect responsible for Design/Development/Implementation of Data/BI flows within EQ Compliance Data Warehouse.\nGather Functional requirements from Global Users & transform them into Technical BI/ETL specifications.\nPerform Data Analysis/Profiling\nDefine/Implement Data Governance best practices within the data warehouse.\nDesign/Develop Data Conversion Processes - Load data from disparate sources into Netezza/DW.\nRationalize & Optimize the daily/weekly/monthly loads in Data warehouse .\nDesign & Build Custom Reports using Business Objects for Users/Clients.',
#    'Skills: Data Warehousing · SDLC · Business Intelligence · Software Project Management'],
#   ['Senior Data Warehouse & BI Developer',
#    'Credit Suisse',
#    'Sep 2009 - May 2012 · 2 yrs 9 mos',
#    'Eleven Madison Ave, New York, NY - 10010',
#    'Senior Data Warehouse Developer responsible for building/maintaining critical data feeds to prime services data warehouse. \nGather user requirements followed by transforming them into functional & technical specifications.\nBuild ETL flows to load data into the reporting layer and other downstream applications.\nParse & Load unstructured data (PDF/AFP files) into Data warehouse.\nDesign/Develop database jobs for scheduled daily/weekly/monthly data loads.\nDesign/Develop Client Reporting flows. Optimize Throughput on Report Outputs.\nProvide Production support for overnight batch cycles.',
#    'Skills: Data Warehousing · SDLC · Business Intelligence · Software Project Management'],
#   ['Data Warehouse Engineer',
#    'Juniper Networks',
#    'Sep 2008 - Sep 2009 · 1 yr 1 mo',
#    '1201 Mathilda Ave, Sunnyvale, CA',
#    'Data Engineer responsible for design/development/testing & implementation of Data Migration jobs for the Data Warehouse.\nImplement the data flows as part of overall Siebel CRM Initiative.\nBuild Functional & Technical specifications document based on user requirements.\nDesign/Create Data Conversion jobs in oracle using PL/SQL .\nWork with the users to debug existing production issues with client reports.\nPost-implementation support and documentation.',
#    'Skills: Data Warehousing · SDLC'],
#   ['Data Warehouse Engineer',
#    'VEDICSOFT',
#    'Sep 2007 - Sep 2008 · 1 yr 1 mo',
#    '100 Wood Ave, Iselin, NJ - 08830',
#    'Responsible for integrating data from disparate systems like DB2/Sybase/SQL Server/VSAM/XML/Etc.\nCreate Database scripts for moving data between the environments \nWork with the Client to manage the overall product delivery/support.\nClearly documenting the end to end process starting from user requirements/tech specs to post-\ndeployment support/user training.',
#    'Skills: Data Warehousing · SDLC'],
#   ['Application Developer',
#    'Electronics Corporation of India Limited (ECIL) · Internship',
#    'Apr 2005 - Apr 2006 · 1 yr 1 mo',
#    'Application Developer for underground mining technology project.\nDevelop the code required for underground mining electronic alarm systems.\nProvide clear documentation to the user.']],
#  [['Reltio',
#    '6 yrs',
#    'Field Chief Technology Officer',
#    'Full-time',
#    'Aug 2022 - Present · 2 mos',
#    'Technology Director - Office of the CTO',
#    'Full-time',
#    'Sep 2021 - Aug 2022 · 1 yr',
#    'Director Center of Excellence Innovation',
#    'Jul 2019 - Aug 2022 · 3 yrs 2 mos',
#    'Manager of Customer Success Architecture',
#    'Oct 2016 - Jun 2019 · 2 yrs 9 mos',
#    'Responsible for the initial creation of Customer Success Architecture team.  \nLeading technical guidance for existing customers.  \nResponsible for a team that manages 40M+ in ARR.\nResponsible for 50% YoY growth within existing customer accounts.\nExpert in Graph, Master Data Management, Big Data storage and movement, Cloud deployment \n\nSetup and management of new Technical Account Services team\nGrown business from $0 to over $1M in revenue\nManagement of existing Technical Account Managers'],
#   ['Solution Partner', 'Knowledgent', 'Nov 2014 - Oct 2016 · 2 yrs'],
#   ['Senior Engagement Manager - IBM Practice Lead',
#    'Tata Consultancy Services',
#    'Jun 2013 - Nov 2014 · 1 yr 6 mos',
#    'Providing product agnostic MDM expertise across all industries and sectors. Responsible for leading the technical teams of multiple accounts for deploying MDM product lines including but not limited to (IBM MDM Standard Edition, IBM MDM Advanced Edition, and Informatica MDM). \n\nSupporting services sales teams with new and existing customers in order to make sure the transition to delivery goes smoothly and effortlessly for the client.\n\nProviding technical expertise and leadership on all IBM MDM engagements. Focused on account growth and successful delivery of all IBM MDM programs.'],
#   ['IBM',
#    '3 yrs 8 mos',
#    'Principal Consultant',
#    'Feb 2011 - Jun 2013 · 2 yrs 5 mos',
#    "Provide technical sales support and architecture for Master Data Management implementations across both commercial and federal practices across North America.\n\nSupporting software and services sales teams for both new and existing customers.\n\nResponsible for defining and executing both technical and project management aspects of services contracts for IBM's Information Management brand as a Master Data Management solution architect.",
#    'Senior Consultant',
#    'Nov 2009 - May 2011 · 1 yr 7 mos',
#    'Senior Consultant for Initiate Master Data Management Services.'],
#   ['Data Engineer',
#    'Blackstone Technology Group',
#    'Jul 2008 - Nov 2009 · 1 yr 5 mos',
#    'Assessed current source systems on what data they contain and reviewing technical documentation to determine how to extract it.\nLed data modeling effort for multiple enterprise systems.\nOrganized and led system design working groups to advise on the best practices with development.\nProvided all database and BI technical support for DHS Recovery Act and FLEET Management programs.\nDesigned and implemented data warehouse, data marts, and ETL packages for transfer of data.'],
#   ['Database Modeler',
#    'IBM Corporation',
#    'Feb 2007 - Jul 2008 · 1 yr 6 mos',
#    '3 \nDeveloped common physical data model for a worldwide distributed system.\nResolved data integrity and data transfer issues by implementing ETL packages and normalized transactional data model.\nDeveloped multiple PL-SQL procedures and triggers.\nReviewed internal US Army message queue product.\nHelped develop security model and assist with the C&amp;A process.'],
#   ['Software Engineer',
#    'Northrop Grumman Corporation',
#    'Jun 2005 - Dec 2006 · 1 yr 7 mos',
#    'Captured and documented business rules for migrating a legacy application to a web based platform.\nWorked with JAVA, HTML, and SQL technologies in the development of transactional data model and JAVA web application.\nProvided multiple iterations of the application in a rapid application development environment.']],
#  [['Principal PMT / Senior Manager of Product',
#    'Amazon Web Services (AWS) · Full-time',
#    'Aug 2022 - Present · 2 mos',
#    'Seattle, Washington, United States',
#    "I lead product for Quicksight 'Q', a way for everyday businesspeople to answer data questions without learning complex analytical tools or becoming experts in esoteric data models."],
#   ['Director, Technical Product Management and Data Science',
#    'Qumulo · Full-time',
#    'Aug 2021 - Jul 2022 · 1 yr',
#    'Seattle, Washington, United States',
#    "I lead product for Qumulo's cloud and our Data Science team.  Our cloud is the industry's leading storage solution across Azure, AWS, and GCP.  With an NPS of 88, customers love the simplicity, transparency, speed, and scale of our unique software solution.  Our Data Science team powers the organization with insights that guide our decisions to have more impact."],
#   ['Tableau Software',
#    'Full-time · 6 yrs',
#    'Senior Director of Product Management',
#    'Aug 2020 - Aug 2021 · 1 yr 1 mo',
#    'Seattle, Washington, United States',
#    "I lead product strategy to reach and engage users of Tableau's Enterprise SaaS and PaaS platform.  Our goal is to make data broadly available in organizations so people have the information they need to make better decisions quickly.  We deliver simple and engaging products that enable business users to discover useful data insights and share them with others in a secure and governed context leveraging AI and human intelligence. ",
#    'New in Tableau Catalog: Improved search and monitoring for data quality warnings',
#    "Our team's new search platform underpins Tableau Server, Online, and Public. ",
#    'Analytics for anyone, anywhere, with any data: a TC20 product roadmap recap',
#    'Product improvements to increase analytics engagement delivered by our team.',
#    'Introducing Metrics, headlines for your data',
#    'An example of how our team is bringing fast, simple and useful ways for business users to stay up to date with data.',
#    'Director, Product Management',
#    'Oct 2017 - Aug 2020 · 2 yrs 11 mos',
#    'Greater Seattle Area',
#    'I was head of product for Tableau Public, Tableau Mobile, and Tableau Server Experience.  I built a team from 1 to 10 PMs including two managers of PM.  Our goal was to make data more accessible to more people.  We updated products to simplify content discovery, and delivered personalized data experiences.',
#    'A new home page for Tableau Server and Tableau Online makes browsing personal (now in beta)',
#    'How we redesigned the Tableau Server landing experience to be more personally relevant.',
#    'Your journey to amazing mobile dashboards',
#    'A talk I gave with one our outstanding mobile SCs at Tableau Conference. ',
#    'Making mobile-friendly data visualizations with Tableau 2019.1',
#    'Mobile responsive capabilities designed specifically to work with pixel-perfect dashboards our team brought to Tableau Server, Online, and Public ',
#    'Staff Product Manager',
#    'Sep 2015 - Sep 2017 · 2 yrs 1 mo',
#    'Greater Seattle Area',
#    'I came to Tableau at a time of rapid (100%) growth to start up a new team building a 0->1 SaaS and Mobile focused analytics product.  I worked with the founders and lead our team through early concepting and a couple pivots until we found a good fit, delivering Data Alerts.  I exited this role by hiring a PM under me to take our ideas forward.',
#    'Save time with data-driven alerts in Tableau 10.3',
#    'Data Alerts was a pivot from our original Mobile + SaaS focused strategy better aligned to customer needs.  We eventually came back around to the idea and shipped Metrics in my next role.'],
#   ['Principal Manager of PM (Lead) - Windows Phone, MSN',
#    'Microsoft · Full-time',
#    'Oct 2009 - Sep 2015 · 6 yrs',
#    'Redmond, WA',
#    "I lead product for the App Store for Windows 10 and Windows Phone, and MSN's AI/ML headline optimizer.  In this role I managed a team of 5 PMs.  Our work employed design thinking, UXR, and XFN with Marketing and Planning teams to conceive and direct work with dev teams to deliver products that aligned to overall organizational product strategy and delivered on articulated business requirements.",
#    'Windows Phone 8: In App Purchase & Developer Center',
#    "A talk I gave showing developers how to monetize using my team's newly developed in-app commerce API.",
#    'Windows Phone and Windows: Store and Dev Center',
#    'A talk and demo for the new app store for developer customers to understand how end users can discover their products.',
#    'msn_new_homepage.jpg',
#    "Our team launched the new MSN homepage launched with AI/ML driven optimized headlines.  Editors would create a pool of available headlines and our team's tech figured out in real time which were most popular with customer segments.  We delivered a 75% lift in clicks on sections we optimized."],
#   ['Microsoft',
#    '9 yrs 10 mos',
#    'Release Program Manager - Virtual Earth',
#    'Full-time',
#    'Mar 2008 - Mar 2009 · 1 yr 1 mo',
#    'I was the first release manager for this newly formed team of 300.  Put in place scalable project management practices and tools that helped leaders to align efforts across a highly interdependent set of services.',
#    'Program Manager - Microsoft Access',
#    'Full-time',
#    'Feb 2003 - Mar 2008 · 5 yrs 2 mos',
#    'I lead product for Access reporting capabilities, and ran our developer community programs. ',
#    'Software Engineer',
#    'Jun 1999 - Feb 2003 · 3 yrs 9 mos',
#    'I was an engineer on the Windows 9X kernel team and early versions of SharePoint.']],
#  [['Shorelight',
#    '8 yrs 3 mos',
#    'Vice President of Data Science, Analytics and Strategy',
#    'Full-time',
#    'Nov 2021 - Present · 11 mos',
#    "I lead Shorelight's data science and analytics divisions, with four major focus areas - Advanced Analytics and Data Science, Data Product Development, Analytics Strategy, and Analytics Content Strategy.",
#    'Vice President of Analytics',
#    'Sep 2018 - Jan 2022 · 3 yrs 5 mos',
#    'Boston',
#    "I lead Shorelight's analytics and data science division, managing our FutureBright analytics platform, which is our end-to-end tool for BI, predictive analytics, and market research. ",
#    'Chief of Staff',
#    'Jan 2016 - Aug 2018 · 2 yrs 8 mos',
#    "Reporting to the CEO during a time of hyper growth, my role was to help expand the footprint of the CEO in three specific ways - (1) drive the use of analytics and data-driven decision-making throughout the organization; (2) run board meetings and the creation of the quarterly board package; and (3) run long-term strategic projects that didn't clearly fall within any one function. ",
#    'Associate Director, Market Analytics',
#    'Jul 2014 - Jan 2016 · 1 yr 7 mos',
#    'Boston, Massachusetts'],
#   ['The College Board',
#    '2 yrs 9 mos',
#    'Greater New York City Area',
#    'Assistant Director, International Market Analytics',
#    'Jun 2013 - Jun 2014 · 1 yr 1 mo',
#    "I analyze international student mobility trends and use data to solve organizational challenges, but I think more importantly I help present that data in ways that can have the most impact with internal and external constituents.  \n\nEveryday I implement the advice given by famous astrophysicist, Neil de Grasse Tyson, who said of education “You can put the truth out there and they either buy your book or they don't.  Well that's not being an educator.  Being an educator is not only getting the truth right, but there's got to be an act of persuasion.  You have to say, here are the facts, and here is a sensitivity to your state of mind… and it's the combination of the facts and the sensitivity that creates impact.”",
#    'Coordinator, International Services',
#    'Oct 2011 - May 2013 · 1 yr 8 mos',
#    'As the coordinator on the international team I managed large and small-scale research projects based on the data of all international students taking the SAT, AP exams, and the PSAT.  I also designed country-specific strategic plans for qualified educational markets outside the US.  I served as the liaison between The College Board and its constituents for the distribution of data.  I also created special reports and presentations for constituents at the US Department of State (A/OS schools) and for specific domestic and overseas conferences and workshops.  Finally, I managed the redesign of how The College Board collects, manages, and uses data of international students.'],
#   ['Universidad San Ignacio de Loyola',
#    '1 yr 6 mos',
#    'Coordinator, Bilingual Program',
#    'Mar 2011 - Aug 2011 · 6 mos',
#    "The Bilingual Program at San Ignacio University consists of content courses taught in English.  From art and architecture to agriculture and engineering, the program offers 60 bilingual courses which are integrated into the 6 different curriculum areas.  \n\nRoughly 10% of the student body (700 - 800 students) choose to take bilingual courses each semester, and as the Coordinator of the program I was responsible for teacher observation and feedback as well as teacher training.  I was also responsible for data collection and analysis, and I was involved in University-wide initiatives to integrate the bilingual program into each of the University's discipline areas.",
#    'Teacher',
#    'Mar 2010 - Aug 2011 · 1 yr 6 mos',
#    'Lima, Peru',
#    'I taught 4 classes per semester:\n\n1.  Business Administration and Business Plan Creation\n2.  General Management\n3.  Introduction to Business\n4.  The Global Understanding Seminar'],
#   ['Advanced English Professor',
#    'Colegio Santa Maria Marianistas',
#    'Mar 2009 - Dec 2010 · 1 yr 10 mos',
#    'Colegio Santa Maria is an all-boys private school in Lima, Peru.  With over 1,000 high school students, it is considered one of the best high schools in Peru.  \n\nI was responsible for teaching Advanced English to seniors.  I was also the SAT and TOEFL preparation teacher.  \n\nI was a Tutor (homeroom teacher) for the 8th grade class as well as the English teacher for the 8th graders.'],
#   ['Strategy Analyst',
#    'YRC Worldwide',
#    'Mar 2006 - Dec 2008 · 2 yrs 10 mos',
#    'Developed and maintained pricing for Truckload Department.\nDeveloped customer specific prices using costing and yield strategies for Specialized pricing services.\nUltimately tried to find a balance between volume and yield, and how prices affected those factors.']],
#  []]

# %%
list_of_about
# Out:
# [['About',
#   'Experienced in building and leading teams on projects covering the entire spectrum of Data Science and Analytics. In-depth knowledge of Mathematical and Statistical Modeling, Machine Learning, Programming, Data Warehousing and Data Engineering techniques. Background in working for start-ups, global organizations and in academia. '],
#  ['About',
#   '18+ years’ experience driving strategic growth and product launches for leading retail and technology companies by providing product vision that is differentiated and delivers unique value based on customer demands.  Strategic and tactical visionary providing cross-functional leadership – bridging gaps between different functions, most notably between engineering-oriented teams, operations, finance, and marketing. Highly competitive, passionate, persuasive and articulate.  M.S. in Engineering and M.B.A. in Management/Strategy.  \n\nDemonstrated success record in\n\uf0a7\tDefining overall product strategy and vision, market/product requirements, and product roadmaps\n\uf0a7\tEstablishing recognized technical and thought leadership for my products and company for both customers and internal teams\n\uf0a7\tPresenting to C-level management, customers and industry conferences\n\uf0a7\tNegotiating and executing highly complex, multi-million dollar technology supplier and partner relationships with companies such as VeriFone, TNS, AJB, etc. \n\uf0a7\tRecruitment and team building skills, key decision maker in the recruitment and development of key employees, consultants, and outsource-vendors. Motivating staff to peak performance levels\n\uf0a7\tExcellent interpersonal dexterity with proven ability to drive consensus, improve collaboration, and lead by influence\n\uf0a7\tWorking across business teams and operating groups to coordinate resources, determine framework, work on forecasting, budgeting and defining of program performance and results\n\uf0a7\tGAP analysis, SWOT analysis, Risk analysis and Cost/Benefit Analysis\n\nCORE COMPETENCIES\n• Product Vision & Roadmaps \t\t\t• Product Launch & Marketing\t\t• Business Case Development • Talent Acquisition & Staff Development\t\t• Strategic Partnership Negotiation\t\t• Profit & Loss \t\n• Cross – Functional Stakeholder Engagement \t• Competitive & Market Analysis \t \t• Strategic Planning'],
#  ['About',
#   'Former experimental particle physicist and data scientist, now doing software engineering and management at ProtonMail.'],
#  []]
