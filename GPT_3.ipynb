# %%
# !pip install happytransformer
# Out:
# ...
#      |████████████████████████████████| 127 kB 65.4 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 48.9 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
from happytransformer import HappyGeneration
gpt_neo = HappyGeneration(model_type="GPT-NEO", model_name="EleutherAI/gpt-neo-125M") 

print (gpt_neo)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# Exception ignored in: <function tqdm.__del__ at 0x7f6f93ebc9e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tqdm/std.py", line 1161, in __del__
#     def __del__(self):
# KeyboardInterrupt
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/526M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]
# ...

# %%
from happytransformer import GENSettings
prompt='Create email from bullet points\n[[Preceding email:]]\nHi Thomas,\n\nfor the following season I want to order\n\n- 5 pieces of the coat with the product number 34534\n- 3 jeans with the number 43544\n\nThank you!\nJohn\n[[Bullets:]]\n- delivered by sunday\n[[Response Draft:]]'
top_k_sampling_settings = GENSettings(do_sample=True, top_k=50, max_length=100, min_length=10)
output_top_k_sampling = gpt_neo.generate_text(prompt, args=top_k_sampling_settings)

print (output_top_k_sampling.text)
# iphones are very good for keeping track of calls
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# - delivered by 10.30 am from Mckenzie, St. Joseph
#
# I just wish I could get back home
#
# - I got a new pair from my father
# - I have a new pair of sneakers
# - I haven't had a gift in ages
# - I've only had about two dozen pairs in my life
# - No shoes are going to be available for sale
# - I don't know if they could fit into a backpack?
# - No, I don

# %%
# !pip install openai

# %%
API_KEY= ''

# %%
import openai
openai.api_key=API_KEY

# %%
response = openai.Completion.create(
  engine="davinci-instruct-beta",
  prompt="""Create email from bullet points\n[[Preceding email:]]\nHi Thomas,\n\nfor the following season I want to order\n\n- 5 pieces of the coat with the product number 34534\n- 3 jeans with the number 43544\n\nThank you!\nJohn\n[[Bullets:]]\n- delivered by sunday\n [[Linkedin profile: • 19+ Years of rich experience spanning across multiple types of industries, domains, and technologies]].
• A hands-on data scientist and technologist with 9 years of intense experience in data science and educational background in MLAI , business and engineering
• An agile leader who can deal ambiguity comfortably and overcome complex challenges
• Capable of building high-performance teams comprising of Solution Architects, Data Scientists, Data Engineers etc. 
• A panelist and guest lecturer for master level data science programs
• Expertise in data product development, Client Relationship Management and business consulting
• Experience in working with C-level executives.
• Looking forward to play key role in MLAI, NLP, AI strategy, and consulting
Functions: Strategy, Supply Chain Management, Operations
Domain: Banking, Finance, Manufacturing, Healthcare, Legal]\n[[Response Draft:]]""",
  temperature=0,
  max_tokens=200,
  top_p=1
)
# Expected outcome:
# Hi John,
#
# I am happy to confirm that we will be able to deliver your order by Sunday.
#
# Thank you!
# Thomas

# %%
help(openai.Completion.create)
# Out:
# Help on method create in module openai.api_resources.completion:
#
# create(*args, **kwargs) method of builtins.type instance
#     Creates a new completion for the provided prompt and parameters.
#
#     See https://beta.openai.com/docs/api-reference/completions/create for a list
#     of valid parameters.

# %%
# input_text = """Create email from bullet points\n[[Preceding email:]]\nHi Thomas,\n\n wedding anniversary \n\n congratulate for awarded employee of the year\n\nfor the following season I want to order\n\n- 5 pieces of the coat with the product number 34534\n- 3 jeans with the number 43544\n\nThank you!\nJohn\n[[Bullets:]]\n- delivered by sunday\n[[Response Draft:]]
# [[linkedin:]]\n """

input_text = """Create email from bullet points\n[[Preceding email:]]\nHi Thomas,\n\n congratulat death anniversary \n\n congratulate for awarded employee of the year\n\nfor the following season I want to order\n\n- 5 pieces of the coat with the product number 34534\n- 3 jeans with the number 43544\n\nThank you!\nJohn\n[[Bullets:]]\n- delivered by sunday\n[[Response Draft:]]
[[linkedin:]]\n """

rephrased_content = openai.Completion.create(
    engine="davinci-instruct-beta",
    prompt=f"Rewrite the text to be elaborate and polite.\nAbbreviations need to be replaced.\nText: {input_text}\nRewritten text:",
    temperature=0.8,
    max_tokens=len(input_text)*3,
    top_p=0.8,
    best_of=2,
    frequency_penalty=0.0,
    presence_penalty=0.0)

# %%
rephrased_content
# Out:
# <OpenAIObject text_completion id=cmpl-5r3fc7l99BFy0MNVthyRi4NbUA8WU at 0x7fd5b3e263b0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nDear Thomas,\n\nCongratulations on your death anniversary.\nCongratulations on being awarded employee of the year.\n\nI would like to order the following for the following season:\n\n- 5 pieces of the coat with the product number 34534\n- 3 jeans with the number 43544\n\nThank you!\n\nJohn"
#     }
#   ],
#   "created": 1663327176,
#   "id": "cmpl-5r3fc7l99BFy0MNVthyRi4NbUA8WU",
#   "model": "davinci-instruct-beta",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 131,
#     "prompt_tokens": 126,
#     "total_tokens": 257
#   }
# }

# %%
document_list=["""Chief Technology Officer at Cendyn
Miami-Fort Lauderdale Area
"Experienced and passionate goal-oriented technology executive with respected leadership skills, proven hands-on technical expertise in software engineering, innovation and product development. Over 30 years of successfully planning, directing and delivery of technology systems, products and solutions including large scale integrations, end to end applications and big data. 
 
 Very adept with agile teams and rapid development cycles. Proven ability to recruit, build, develop, and revitalize development and operational teams leveraging proven resilience and wisdom to lead and motivate teams to their highest achievement through difficult challenges of constant business changes. 
 
 Experience working in large companies such as IBM, Yahoo and Motorola. Also very passionate about building up high performing engineering organizations from scratch or early stages such as Netspeak, DayJet and Interclick. 
 
 Industry experience has ranged from operating systems development, Voice over IP, aviation, and online advertising. Technology scope has varied from Microsoft based tools to Linux and open source."
Chief Technology Officer
Mar 2020 - Present · 2 yrs 6 mos
Cendyn · Full-time

CTO
Jan 2018 - Mar 2020 · 2 yrs 3 mos
ERP Maestro, Inc
CTO
Technology Consultant
May 2015 - Jan 2018 · 2 yrs 9 mos
Consultant
Looking for a challenging opportunity in an energetic and motivated technology company. I want to apply my years of product and technology innovation and management to a leading edge and fast paced company culture and environment. I want to take my proven record of successful development or teams and products to the next level and help drive your company to greater success.
Consultant
May 2017 - Sep 2017 · 5 mos
Kaplan University

Senior Director, Data Management Platform and Targeting
Jan 2010 - Mar 2015 · 5 yrs 3 mos
Yahoo!
"Managed Yahoo engineering teams across two continents including system development, big data ingestion and analysis, audience data warehouse, and data modeling related to user targeting and first/third party data acquisition. 
 - Utilized agile based development processes, integrating Product, Engineering and Support
 - Implemented next generation Data Acquisition Platform using high performance web services for first/third party data integration system utilizing Hadoop cluster, Zookeeper and Oracle DB.
 - Development of Audience Data Warehouse utilizing Hadoop and Druid technology providing for a robust, scalable and near real-time analytic and reporting platform.
 o Development of Objective Based Targeting system using Hadoop and search based technology. 
  
 VP Engineering (Genome) - Led the engineering activities and teams at Genome developing systems for premium targeted online advertising solutions. Genome (interclick) was a public company that was acquired by Yahoo. interclick’s proprietary advertising and advanced user targeting technology solutions enabled it to dramatically improve data targeted solutions and optimized returns for advertisers across a variety of pooled premium supply (website) sources. 
 - Development of application and systems utilizing Microsoft technology such as Visual Studio/C# and SQL Server.
  - Audience targeting and Ad management applications
  - Ad serving system
  - Third Party Data Integration platform
  - Directed the development of Business Intelligence system utilizing three tiered model using Microstrategy, Infomatica and Netezza (later Vertica). 
  - Development of event based analytic/targeting DB utilizing in memory version of ParAccel. System handled 1 billion user records, ~20k events/sec and data storage of about 32gbytes per day.
  - Development of high performance user profile and lookup system to serve real time ad serving. Based on AeroSpike (NoSQL) technology storing user profiles for ~250 million active users."
Product Management, Web Services, REST, Software Development, Web Applications, .NET, Technical Leadership, System Software, Scalability, C#, NoSQL Database, Big Data, Software, Scrum, Product Engineering, Architecture, Cloud Computing, Software Engineering, Management, SaaS, Microsoft SQL Server, Software Products, Product Delivery, Technology Development, Agile Methodologies, Engineering Management, Distributed Systems, Enterprise Software, Integration, XML, Visual Studio
"""]

# %%
response = openai.Answer.create(
 search_model="ada",
 model="curie",
 question="What are the main skills",
 documents=document_list,
 examples_context="In 2017, U.S. life expectancy was 78.6 years.",
 examples=[["What is human life expectancy in the United States?","78 years."]],
 max_tokens=50,
 stop=["\n", "<|endoftext|>"],
)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-22-5082c0d10e84> in <module>
#       7  examples=[["What is human life expectancy in the United States?","78 years."]],
#       8  max_tokens=50,
# ----> 9  stop=["\n", "<|endoftext|>"],
#      10 )
#
# /usr/local/lib/python3.7/dist-packages/openai/api_resources/answer.py in create(cls, **params)
#      10     def create(cls, **params):
#      11         instance = cls()
# ---> 12         return instance.request("post", cls.get_url(), params)
#
# /usr/local/lib/python3.7/dist-packages/openai/openai_object.py in request(self, method, url, params, headers, stream, plain_old_data, request_id, request_timeout)
#     184             headers=headers,
#     185             request_id=request_id,
# --> 186             request_timeout=request_timeout,
#     187         )
#     188
#
# ...
